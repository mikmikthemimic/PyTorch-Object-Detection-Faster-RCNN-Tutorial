# %% [markdown]
# SET-UP [Run sa terminal in the virtual environment]
# I. Python version = 3.10.x
# II. Run pip commands with "!python -m pip <commands>"

# %%
# !git clone https://github.com/mikmikthemimic/PyTorch-Object-Detection-Faster-RCNN-Tutorial.git
# %cd PyTorch-Object-Detection-Faster-RCNN-Tutorial/
# %cd C:\Users\abiga\OneDrive\Documents\GitHub\PyTorch-Object-Detection-Faster-RCNN-Tutorial
# Out:
# C:\Users\abiga\OneDrive\Documents\GitHub\PyTorch-Object-Detection-Faster-RCNN-Tutorial

# %%
# !python -m pip install -r requirements_no-hash.txt
# Out:
# Ignoring appnope: markers 'python_version >= "3.10" and python_version < "4.0" and (platform_system == "Darwin" or sys_platform == "darwin")' don't match your environment
# Ignoring exceptiongroup: markers 'python_version >= "3.10" and python_version < "3.11"' don't match your environment
# Ignoring pexpect: markers 'python_version >= "3.10" and python_version < "4.0" and sys_platform != "win32"' don't match your environment
# Ignoring ptyprocess: markers 'python_version >= "3.10" and python_version < "4.0" and (os_name != "nt" or sys_platform != "win32")' don't match your environment
# Ignoring tomli: markers 'python_version >= "3.10" and python_version < "3.11"' don't match your environment
# ...
#   Using cached aiohttp-3.8.4.tar.gz (7.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
# ...

# %%
import neptune.new as neptune
from getpass import getpass

my_api_token = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIzNmE3MzZjYS01MDUxLTQ2YjYtOGU3ZC04YzQwNjg4NmJiZDcifQ=="
my_project = "mikmikthemimic/GM-Thesis3"

print("This is running.")
# Out:
# This is running.

# %%
run = neptune.init_run(api_token=my_api_token, project=my_project)
print("This is running.")
# Out:
# https://app.neptune.ai/mikmikthemimic/GM-Thesis3/e/GMT3-11
# Info (NVML): NVML Shared Library Not Found. GPU usage metrics may not be reported. For more information, see https://docs.neptune.ai/you-should-know/what-can-you-log-and-display#hardware-consumption
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.
# This is running.

# %%
# !git pull
print("This is running.")

# %%
run.stop()
print("Hypothetical Stop")
# Out:
# Shutting down background jobs, please wait a moment...
# Done!
# Waiting for the remaining 1 operations to synchronize with Neptune. Do not kill this process.
# All 1 operations synced, thanks for waiting!
# Explore the metadata in the Neptune app:
# https://app.neptune.ai/mikmikthemimic/GM-Thesis3/e/GMT3-11
# Hypothetical Stop
